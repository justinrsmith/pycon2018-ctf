# %%
from pandas import read_csv

# %%
df = read_csv('periodic_table.csv')

# %%
df.head()
# Out:
#    atomicNumber  symbol        name    atomicMass  cpkHexColor  \
# 0             1      H     Hydrogen    1.00794(4)       FFFFFF
# 1             2     He       Helium   4.002602(2)       D9FFFF
# 2             3     Li      Lithium      6.941(2)       CC80FF
# 3             4     Be    Beryllium   9.012182(3)       C2FF00
# 4             5      B        Boron     10.811(7)       FFB5B5
#
#    electronicConfiguration   electronegativity   atomicRadius  ionRadius  \
# 0                     1s1                 2.20           37.0        NaN
# 1                     1s2                  NaN           32.0        NaN
# 2                [He] 2s1                 0.98          134.0    76 (+1)
# 3                [He] 2s2                 1.57           90.0    45 (+2)
# 4            [He] 2s2 2p1                 2.04           82.0    27 (+3)
#
#     vanDelWaalsRadius   ionizationEnergy   electronAffinity  oxidationStates  \
# ...

# %%
df = df[df[' groupBlock'] == "transition metal"]

# %%
df = df[df[' boilingPoint'] < 5000]

# %%
df.loc[df['density'].idxmax()]
# Out:
# atomicNumber                                      77
#  symbol                                          Ir
#  name                                        Iridium
#  atomicMass                               192.217(3)
#  cpkHexColor                                  175487
#  electronicConfiguration          [Xe] 4f14 5d7 6s2
#  electronegativity                               2.2
#  atomicRadius                                    137
#  ionRadius                                   68 (+3)
#  vanDelWaalsRadius                               NaN
#  ionizationEnergy                                880
#  electronAffinity                               -151
#  oxidationStates            -3, -1, 1, 2, 3, 4, 5, 6
#  standardState                                 solid
#  bondingType                                metallic
#  meltingPoint                                   2739
#  boilingPoint                                   4701
# density                                        22.65
# ...
